# %%
import pandas as pd

# %%
data = pd.read_csv('zomato.csv')

# %%
data.head()
# Out:
#    Restaurant ID                        Restaurant Name  Country Code  City  \
# 0        3400025                             Jahanpanah             1  Agra
# 1        3400341                    Rangrezz Restaurant             1  Agra
# 2        3400005                Time2Eat - Mama Chicken             1  Agra
# 3        3400005         Mama Chicken Mama Franky House             1  Agra
# 4        3400021  Chokho Jeeman Marwari Jain Bhojanalya             1  Agra
#
#                                              Address     Locality  \
# 0  E 23, Shopping Arcade, Sadar Bazaar, Agra Cant...   Agra Cantt
# 1  E-20, Shopping Arcade, Sadar Bazaar, Agra Cant...   Agra Cantt
# 2        Main Market, Sadar Bazaar, Agra Cantt, Agra   Agra Cantt
# 3  A-17, Shoping Arcade, Sadar Bazaar, Agra Cantt...   Agra Cantt
# 4  1/48, Delhi Gate, Station Road, Raja Mandi, Ci...  Civil Lines
#
#     Locality Verbose  Longitude   Latitude  \
# 0   Agra Cantt, Agra  78.011544  27.161661
# 1   Agra Cantt, Agra   0.000000   0.000000
# 2   Agra Cantt, Agra  78.011608  27.160832
# 3   Agra Cantt, Agra  78.011627  27.161854
# 4  Civil Lines, Agra  77.998364  27.195759
#
#                                             Cuisines  ...            Currency  \
# 0                              North Indian, Mughlai  ...  Indian Rupees(Rs.)
# 1                              North Indian, Mughlai  ...  Indian Rupees(Rs.)
# 2                                       North Indian  ...  Indian Rupees(Rs.)
# 3  North Indian, Mughlai, Rolls, Chinese, Fast Fo...  ...  Indian Rupees(Rs.)
# 4                                         Rajasthani  ...  Indian Rupees(Rs.)
#
#   Has Table booking  Has Online delivery  Is delivering now  \
# 0                 0                    0                  0
# 1                 0                    0                  0
# 2                 0                    0                  0
# 3                 0                    1                  0
# 4                 0                    1                  0
#
#    Switch to order menu  Price range  Aggregate rating  Rating color  \
# 0                     0            3               3.9        9ACD32
# 1                     0            2               3.5        9ACD32
# 2                     0            2               3.6        9ACD32
# 3                     0            2               4.3        5BA829
# 4                     0            2               4.5        3F7E00
#
#   Rating text  Votes
# 0        Good    140
# 1        Good     71
# 2        Good     94
# 3   Very Good  31399
# 4   Excellent   4944
#
# [5 rows x 21 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9351 entries, 0 to 9350
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9351 non-null   int64
#  1   Restaurant Name       9351 non-null   object
#  2   Country Code          9351 non-null   int64
#  3   City                  9351 non-null   object
#  4   Address               9351 non-null   object
#  5   Locality              9351 non-null   object
#  6   Locality Verbose      9351 non-null   object
#  7   Longitude             9351 non-null   float64
#  8   Latitude              9351 non-null   float64
#  9   Cuisines              9351 non-null   object
#  10  Average Cost for two  9351 non-null   int64
#  11  Currency              9351 non-null   object
#  12  Has Table booking     9351 non-null   int64
#  13  Has Online delivery   9351 non-null   int64
#  14  Is delivering now     9351 non-null   int64
#  15  Switch to order menu  9351 non-null   int64
#  16  Price range           9351 non-null   int64
#  17  Aggregate rating      9351 non-null   float64
#  18  Rating color          9351 non-null   object
#  19  Rating text           9351 non-null   object
#  20  Votes                 9351 non-null   int64
# dtypes: float64(3), int64(9), object(9)
# memory usage: 1.5+ MB

# %%
df = data[['Restaurant Name','Address','City','Locality','Cuisines','Average Cost for two','Aggregate rating']]

# %%
df.head()
# Out:
#                          Restaurant Name  \
# 0                             Jahanpanah
# 1                    Rangrezz Restaurant
# 2                Time2Eat - Mama Chicken
# 3         Mama Chicken Mama Franky House
# 4  Chokho Jeeman Marwari Jain Bhojanalya
#
#                                              Address  City     Locality  \
# 0  E 23, Shopping Arcade, Sadar Bazaar, Agra Cant...  Agra   Agra Cantt
# 1  E-20, Shopping Arcade, Sadar Bazaar, Agra Cant...  Agra   Agra Cantt
# 2        Main Market, Sadar Bazaar, Agra Cantt, Agra  Agra   Agra Cantt
# 3  A-17, Shoping Arcade, Sadar Bazaar, Agra Cantt...  Agra   Agra Cantt
# 4  1/48, Delhi Gate, Station Road, Raja Mandi, Ci...  Agra  Civil Lines
#
#                                             Cuisines  Average Cost for two  \
# 0                              North Indian, Mughlai                   850
# 1                              North Indian, Mughlai                   700
# 2                                       North Indian                   500
# 3  North Indian, Mughlai, Rolls, Chinese, Fast Fo...                   600
# 4                                         Rajasthani                   400
#
#    Aggregate rating
# 0               3.9
# 1               3.5
# 2               3.6
# 3               4.3
# 4               4.5

# %%
ser = ', '.join(x for x in df['Cuisines'].unique())

# %%
ser = set(ser.split(', '))

# %%
ser
# Out:
# {'Afghani',
#  'African',
#  'American',
#  'Andhra',
#  'Arabian',
#  'Armenian',
#  'Asian',
#  'Assamese',
#  'Awadhi',
#  'BBQ',
#  'Bakery',
#  'Bar Food',
#  'Belgian',
#  'Bengali',
#  'Beverages',
#  'Bihari',
#  'Biryani',
#  'British',
#  'Bubble Tea',
#  'Burger',
#  'Burmese',
#  'Cafe',
#  'Cajun',
#  'Cantonese',
#  'Charcoal Grill',
#  'Chettinad',
#  'Chinese',
#  'Coffee',
#  'Continental',
#  'Cuisine Varies',
#  'Deli',
#  'Desserts',
#  'Drinks Only',
#  'European',
#  'Fast Food',
#  'Finger Food',
#  'French',
#  'German',
#  'Goan',
#  'Greek',
#  'Gujarati',
#  'Healthy Food',
#  'Hyderabadi',
#  'Ice Cream',
#  'Indian',
#  'Indonesian',
#  'Iranian',
#  'Israeli',
#  'Italian',
#  'Japanese',
#  'Juices',
#  'Kashmiri',
#  'Kebab',
#  'Kerala',
#  'Korean',
#  'Lebanese',
#  'Lucknowi',
#  'Maharashtrian',
#  'Malaysian',
#  'Malwani',
#  'Mangalorean',
#  'Mediterranean',
#  'Mexican',
#  'Middle Eastern',
#  'Mithai',
#  'Modern Indian',
#  'Momos',
#  'Moroccan',
#  'Mughlai',
#  'Naga',
#  'Nepalese',
#  'North Eastern',
#  'North Indian',
#  'Odia',
#  'Oriya',
#  'Pakistani',
#  'Parsi',
#  'Pasta',
#  'Persian',
#  'Pizza',
#  'Portuguese',
#  'Rajasthani',
#  'Raw Meats',
#  'Roast Chicken',
#  'Rolls',
#  'Salad',
#  'Sandwich',
#  'Seafood',
#  'Singaporean',
#  'South American',
#  'South Indian',
#  'Spanish',
#  'Sri Lankan',
#  'Steak',
#  'Street Food',
#  'Sushi',
#  'Tamil',
#  'Tea',
#  'Tex-Mex',
#  'Thai',
#  'Tibetan',
#  'Turkish',
#  'Vietnamese',
#  'Wraps'}

# %%
df[df['City']== 'Bangalore']
# Out:
#                                       Restaurant Name  \
# 196                                    The 13th Floor
# 197                                  Sultans of Spice
# 198                       Byg Brewski Brewing Company
# 199                                  Bombay Brasserie
# 200                                       Burma Burma
# 201                  The Fatty Bao - Asian Gastro Bar
# 202                                              Toit
# 203                               Three Dots & A Dash
# 204                                1131 Bar + Kitchen
# 205                                  Bombay Brasserie
# 206                                  Glen's Bakehouse
# 207                                            Onesta
# 208                                            Onesta
# 209                                      Brahma Brews
# 210                                      URU Brewpark
# 211                         The Hole In The Wall Cafe
# 212                                ECHOES Koramangala
# 213                                          Truffles
# 214                                        Biergarten
# 215                                   The Black Pearl
# 216                                    The Reservoire
# 217                                        Eat Street
# 218                                  The Bier Library
# 219                                Koramangala Social
# 220                         AB's - Absolute Barbecues
# 221                                          Flechazo
# 222                                            Onesta
# 223                                       Big Pitcher
# 224  The London Curry House - The Royale Senate Hotel
# 225                                         Communiti
# 226                             Olive Bar And Kitchen
# 227                                  The Druid Garden
# 228                                       Big Brewsky
# 229                                              Hoot
# 230                                        Farzi Cafe
# 231                                        Biergarten
# 232                              Windmills Craftworks
#
#                                                Address       City  \
# 196  84/142, 12th And 13th Floor, Barton Center, MG...  Bangalore
# 197  BluPetal Hotel, 60 Jyoti Nivas College Road, K...  Bangalore
# 198  22/123, Byrathi Village, Bidarahalli Hobli, He...  Bangalore
# 199  2989/B, 12th Main Road, HAL 2nd Stage, Indiran...  Bangalore
# 200  607, Ground Floor, 12th Main, Hal 2nd Stage, I...  Bangalore
# 201  610, 3rd Floor, 12th Main, Off 80 Feet Road, I...  Bangalore
# 202  298, 100 Feet Road, Namma Metro Pillar 62, Ind...  Bangalore
# 203  840/1,100 Feet Road, Metro Pillar 56-57, Indir...  Bangalore
# 204  100 Feet Road, HAL 2nd Stage, Indiranagar, Ban...  Bangalore
# 205  2989/B, 12th Main Road, HAL 2nd Stage, Indiran...  Bangalore
# 206         297, 100 Feet Road, Indiranagar, Bangalore  Bangalore
# 207  501, Binnamangala Extension, 1st stage, C.M.H ...  Bangalore
# 208  Site 15, 15th Cross, 100 Feet Road, 4th Phase,...  Bangalore
# 209  Opposite Brigade Palm Springs, 24th Main, 7th ...  Bangalore
# 210  Near Maratt Estate, 4th Phase, JP Nagar, Banga...  Bangalore
# 211  4, 8th Main Road, Koramangala 4th Block, Banga...  Bangalore
# 212  44, 4th B Cross, Koramangala 5th Block, Bangalore  Bangalore
# 213  28, 4th B Cross, Koramangala 5th Block, Bangalore  Bangalore
# 214      4th B Cross, Koramangala 5th Block, Bangalore  Bangalore
# 215  105, 1st A Cross Road, Jyothi Nivas College Ro...  Bangalore
# 216  17th Main Road, JNC Road, Koramangala 5th Bloc...  Bangalore
# 217  11, 80 Feet Road, Opposite Indian Oil Petrol P...  Bangalore
# 218  14, Patel Narayana Reddy Layout, 80 Feet Main ...  Bangalore
# 219  118, Koramangala Industrial Area, Koramangala ...  Bangalore
# 220  90/4, 3rd Floor, Outer Ring Road, Munnekollaly...  Bangalore
# 221  9/1, 1st Floor, Above Surya Nissan, VRR Orchid...  Bangalore
# 222  215, 216 & 220, Devasandra Village, Kasaba Hob...  Bangalore
# 223       4121, LR Arcade, Old Airport Road, Bangalore  Bangalore
# 224  19/3, Kumara Krupa Road, Race Course Road, Ban...  Bangalore
# 225  67 & 68, Brigade Solitaire, Opposite to Advait...  Bangalore
# 226  16, Wood Street, Ashok Nagar, Richmond Road, B...  Bangalore
# 227  40/1, 3rd Floor, Century Corbel Commercial, Sa...  Bangalore
# 228  Behind MK Retail, Before WIPRO Corporate Offic...  Bangalore
# 229  BBMP 2034/69, Block 2, Kaikondrahalli, Varthur...  Bangalore
# 230  202, Level 2, UB City, Vittal Mallya Road, Lav...  Bangalore
# 231  2, Doddanekkundi, Whitefield Road, Mahadevpura...  Bangalore
# 232  331, EPIP Area, Road 5B, Near KTPO, Whitefield...  Bangalore
#
#                         Locality  \
# 196                Barton Centre
# 197  BluPetal Hotel, Koramangala
# 198                       Hennur
# 199                  Indiranagar
# 200                  Indiranagar
# 201                  Indiranagar
# 202                  Indiranagar
# 203                  Indiranagar
# 204                  Indiranagar
# 205                  Indiranagar
# 206                  Indiranagar
# 207                  Indiranagar
# 208                     JP Nagar
# 209                     JP Nagar
# 210                     JP Nagar
# 211        Koramangala 4th Block
# 212        Koramangala 5th Block
# 213        Koramangala 5th Block
# 214        Koramangala 5th Block
# 215        Koramangala 5th Block
# 216        Koramangala 5th Block
# 217        Koramangala 6th Block
# 218        Koramangala 6th Block
# 219        Koramangala 7th Block
# 220                 Marathahalli
# 221                 Marathahalli
# 222                 New BEL Road
# 223             Old Airport Road
# 224             Race Course Road
# 225               Residency Road
# 226                Richmond Road
# 227               Sahakara Nagar
# 228                Sarjapur Road
# 229                Sarjapur Road
# 230                      UB City
# 231                   Whitefield
# 232         Windmills Craftworks
#
#                                               Cuisines  Average Cost for two  \
# 196                          North Indian, Asian, Thai                  2000
# 197                              North Indian, Mughlai                  1300
# 198  Continental, North Indian, Italian, South Indi...                  1600
# 199  Modern Indian, Street Food, Biryani, Desserts,...                  1800
# 200  Asian, Burmese, Bubble Tea, Salad, Tea, Desser...                  1500
# 201             Japanese, Sushi, Asian, Chinese, Momos                  1200
# 202                   Italian, American, Modern Indian                  2000
# 203                              European, Continental                  1300
# 204  Continental, Mughlai, North Indian, Beverages,...                  1500
# 205                                      Modern Indian                  1500
# 206                             Bakery, Desserts, Cafe                   800
# 207                               Pizza, Cafe, Italian                   600
# 208                               Pizza, Cafe, Italian                   600
# 209  Bar Food, Asian, Italian, North Indian, Fast F...                  1900
# 210  Italian, North Indian, Continental, Chinese, A...                  1500
# 211        Cafe, American, Burger, Beverages, Desserts                   600
# 212  Continental, American, Italian, North Indian, ...                   950
# 213  Cafe, American, Coffee, Steak, Beverages, Fast...                   900
# 214  Continental, North Indian, Chinese, Finger Foo...                  2000
# 215              North Indian, European, Mediterranean                  1400
# 216  Continental, North Indian, American, Asian, Ch...                  1400
# 217  North Indian, Chinese, Italian, Street Food, D...                   400
# 218              Continental, North Indian, Pizza, BBQ                  2000
# 219                              Continental, American                  1500
# 220              European, Mediterranean, North Indian                  1400
# 221                 Asian, Mediterranean, North Indian                  1200
# 222                               Pizza, Cafe, Italian                   600
# 223  American, Continental, North Indian, Mediterra...                  1600
# 224  Modern Indian, North Indian, Italian, Continental                  1700
# 225                                        Continental                  1200
# 226            Mediterranean, European, Salad, Italian                  2400
# 227  Asian, Continental, Italian, North Indian, Bev...                  1700
# 228  Finger Food, North Indian, Italian, Continenta...                  1800
# 229                 Continental, Italian, North Indian                  1400
# 230                                      Modern Indian                  1500
# 231         Continental, European, BBQ, Chinese, Asian                  2000
# 232  Continental, Fast Food, Kebab, Beverages, Ital...                  2500
#
#      Aggregate rating
# 196               4.4
# 197               4.1
# 198               4.3
# 199               4.5
# 200               4.7
# 201               4.5
# 202               4.6
# 203               3.9
# 204               4.2
# 205               4.2
# 206               4.0
# 207               4.3
# 208               4.6
# 209               4.3
# 210               4.1
# 211               4.4
# 212               4.7
# 213               4.8
# 214               4.4
# 215               4.1
# 216               4.1
# 217               4.3
# 218               4.4
# 219               4.5
# 220               4.6
# 221               4.4
# 222               4.6
# 223               4.3
# 224               4.5
# 225               4.2
# 226               4.6
# 227               4.1
# 228               4.5
# 229               3.9
# 230               4.4
# 231               4.5
# 232               4.7

# %%
df['City'].unique()
# Out:
# array(['Agra', 'Ahmedabad', 'Allahabad', 'Amritsar', 'Aurangabad',
#        'Bangalore', 'Bhopal', 'Bhubaneshwar', 'Chandigarh', 'Chennai',
#        'Coimbatore', 'Dehradun', 'Faridabad', 'Gangtok', 'Ghaziabad',
#        'Goa', 'Gurgaon', 'Guwahati', 'Hyderabad', 'Indore', 'Jaipur',
#        'Kanpur', 'Kochi', 'Kolkata', 'Lucknow', 'Ludhiana', 'Mangalore',
#        'Mohali', 'Mumbai', 'Mysore', 'Nagpur', 'Nashik', 'Nasik',
#        'New Delhi', 'Noida', 'Ooty', 'Panchkula', 'Patna', 'Puducherry',
#        'Pune', 'Ranchi', 'Secunderabad', 'Shimla', 'Surat', 'Vadodara',
#        'Varanasi', 'Vizag'], dtype=object)

# %%
def RestaurantSearch(City,Cuisine, min_price, max_price):
    zomato_data = df[(df['Cuisines'].apply(lambda x: Cuisine.lower() in x.lower())) &
                (df['City'].apply(lambda x: City.lower() in x.lower())) &
                (df['Average Cost for two']>=min_price) &
                (df['Average Cost for two']<=max_price)]

    zomato_data = df[['Restaurant Name','Address','Average Cost for two','Aggregate rating']]
    zomato_data = zomato_data.sort_values(by='Aggregate rating', ascending=False)
    return zomato_data

# %%
z_data = RestaurantSearch('Bangalore','South Indian', 500,1000)

# %%
response = f"Here are the top 5 matches for your search: \n"
for _, restaurant in z_data.iloc[:5].iterrows():
    t_resp = f" Restaurnat Name: {restaurant['Restaurant Name']}\n Address: {restaurant['Address']}\n Average cost for two: {restaurant['Average Cost for two']} \n Rating is {restaurant['Aggregate rating']} \n {'-'*30} \n"
    response += t_resp

# %%
print(response)
# Out:
# Here are the top 5 matches for your search:
#  Restaurnat Name: Grandson of Tunday Kababi
#  Address: Naaz Cinema Road, Aminabad, Lucknow
#  Average cost for two: 300
#  Rating is 4.9
#  ------------------------------
#  Restaurnat Name: Gelateria Montecatini Terme
#  Address: Goubert Avenue, Next To Alliance Franchaise, White Town, Puducherry
#  Average cost for two: 150
#  Rating is 4.9
#  ------------------------------
#  Restaurnat Name: Indian Accent - The Manor
#  Address: The Manor, 77, Friends Colony, New Delhi
#  Average cost for two: 4000
#  Rating is 4.9
#  ------------------------------
#  Restaurnat Name: Giri Manja's
#  Address: Near Kalikamba Temple, Gopalkrishna Temple Road, Bhavathi, Mangalore Bhavathi
#  Average cost for two: 500
#  Rating is 4.9
#  ------------------------------
#  Restaurnat Name: Sheroes Hangout
#  Address: Opposite The Gateway Hotel, Fatehabad Road, Tajganj, Agra
#  Average cost for two: 0
#  Rating is 4.9
#  ------------------------------

# %%
import re
st = "utkagmail.com"
pat = re.compile(r"\b[\w\.-]+@[\w\.-]+\.\w{2,4}\b")
s = re.search(pat, st)
if s is None:
    print('not ok')
else:
    print('ok')
# Out:
# not ok

# %%
import logging
logging.basicConfig(level=logging.DEBUG, format= "%(funcName)s() - %(lineno)s - %(message)s")

# %%
logging.info("ok")
# Out:
# <module>() - 1 - ok

# %%
df[:5]
# Out:
#                          Restaurant Name  \
# 0                             Jahanpanah
# 1                    Rangrezz Restaurant
# 2                Time2Eat - Mama Chicken
# 3         Mama Chicken Mama Franky House
# 4  Chokho Jeeman Marwari Jain Bhojanalya
#
#                                              Address  City     Locality  \
# 0  E 23, Shopping Arcade, Sadar Bazaar, Agra Cant...  Agra   Agra Cantt
# 1  E-20, Shopping Arcade, Sadar Bazaar, Agra Cant...  Agra   Agra Cantt
# 2        Main Market, Sadar Bazaar, Agra Cantt, Agra  Agra   Agra Cantt
# 3  A-17, Shoping Arcade, Sadar Bazaar, Agra Cantt...  Agra   Agra Cantt
# 4  1/48, Delhi Gate, Station Road, Raja Mandi, Ci...  Agra  Civil Lines
#
#                                             Cuisines  Average Cost for two  \
# 0                              North Indian, Mughlai                   850
# 1                              North Indian, Mughlai                   700
# 2                                       North Indian                   500
# 3  North Indian, Mughlai, Rolls, Chinese, Fast Fo...                   600
# 4                                         Rajasthani                   400
#
#    Aggregate rating
# 0               3.9
# 1               3.5
# 2               3.6
# 3               4.3
# 4               4.5

# %%
ZomatoData  = df

# %%
def RestaurantSearch(City,Cuisine, min_price, max_price, return_top=5):
    logging.info(f"Input City Name: {City}, Cuisine name: {Cuisine}, Price range: {min_price} to {max_price}")
    zomato_data = ZomatoData[(ZomatoData['Cuisines'].apply(lambda x: Cuisine.lower() in x.lower())) &
     (ZomatoData['City'].apply(lambda x: City.lower() in x.lower())) &
     (ZomatoData['Average Cost for two']>=min_price) &
     (ZomatoData['Average Cost for two']<=max_price)
     ]

    zomato_data = zomato_data[['Restaurant Name','Address','Average Cost for two','Aggregate rating']]
    zomato_data = zomato_data.sort_values(by='Aggregate rating', ascending=False)
    return zomato_data.iloc[:return_top]

# %%
results = RestaurantSearch('Bangalore', 'North Indian', 500, 1500)
results
# Out:
# RestaurantSearch() - 2 - Input City Name: Bangalore, Cuisine name: North Indian, Price range: 500 to 1500
#                Restaurant Name  \
# 212         ECHOES Koramangala
# 220  AB's - Absolute Barbecues
# 221                   Flechazo
# 204         1131 Bar + Kitchen
# 197           Sultans of Spice
#
#                                                Address  Average Cost for two  \
# 212  44, 4th B Cross, Koramangala 5th Block, Bangalore                   950
# 220  90/4, 3rd Floor, Outer Ring Road, Munnekollaly...                  1400
# 221  9/1, 1st Floor, Above Surya Nissan, VRR Orchid...                  1200
# 204  100 Feet Road, HAL 2nd Stage, Indiranagar, Ban...                  1500
# 197  BluPetal Hotel, 60 Jyoti Nivas College Road, K...                  1300
#
#      Aggregate rating
# 212               4.7
# 220               4.6
# 221               4.4
# 204               4.2
# 197               4.1

# %%
def format_message(df):
    resp = ""
    for _ , restaurant in df.iterrows():
        r_temp = f" Restaurnat Name: {restaurant['Restaurant Name']}\n Address: {restaurant['Address']}\n Average cost for two: {restaurant['Average Cost for two']} \n Rating is {restaurant['Aggregate rating']} \n {'-'*30} \n"
        resp += r_temp
    return resp

# %%
response = f"Here are the top 5 matches for your search: \n"
response += format_message(results)
print(response)
# Out:
# Here are the top 5 matches for your search:

# %%
import time
import asyncio
async def ok():
    time.sleep(2)
    print('ok')

# %%
print(1)
ok()
print(2)
# Out:
# 1
# 2
# C:\Users\utkar\anaconda3\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: coroutine 'ok' was never awaited
#
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback

# %%
print(1)
loop = asyncio.get_event_loop()
task = loop.create_task(ok())
print(2)
# Out:
# 1
# 2

# %%
import re
def parse_price(raw_price):
    low_price= 0
    high_price = 100000
    temp = re.findall(r'\d+', raw_price)
    res = list(map(int, temp))
    print(res)
    low_list = ['less', '<','within','low','']
    high_list = ['more','>', 'higher']
    # Logic to get the price
    if len(res)>1:
        low_price = res[0]
        high_price = res[-1]
    if len(res) == 1:
        b_flag = [ele for ele in high_list if(ele in raw_price)]
        if len(b_flag) > 0:    
            low_price = res[0]
        else:
            high_price = res[0]
    return low_price, high_price

# %%
parse_price('')
# Out:
# [700]
# (700, 100000)

# %%
- payload: 0-300
      title: Less than Rs.300
    - payload: 300-700
      title: Rs.300 to Rs.700
    - payload: ">700"
      title: More than Rs.700
